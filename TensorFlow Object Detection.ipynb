# %% [markdown]
# # TensorFlow Object Detection API

# %% [markdown]
# - code to clean conda envs: ``conda clean --all``
# - use ``tfodt`` env

# %% [markdown]
# ### Load a Model

# %%
import object_detection

# %%
import tensorflow as tf  
from object_detection.utils import label_map_util 
from object_detection.utils import config_util 
from object_detection.utils import visualization_utils as viz_utils 
from object_detection.builders import model_builder
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[2], line 2
#       1 import tensorflow as tf
# ----> 2 from object_detection.utils import label_map_util
#       3 from object_detection.utils import config_util
#       4 from object_detection.utils import visualization_utils as viz_utils
#
# File ~\AppData\Roaming\Python\Python310\site-packages\object_detection\utils\label_map_util.py:29
#      27 import tensorflow.compat.v1 as tf
#      28 from google.protobuf import text_format
# ---> 29 from object_detection.protos import string_int_label_map_pb2
#      31 _LABEL_OFFSET = 1
#      34 def _validate_label_map(label_map):
#
# File ~\AppData\Roaming\Python\Python310\site-packages\object_detection\protos\string_int_label_map_pb2.py:9
#       7 from google.protobuf import descriptor_pool as _descriptor_pool
#       8 from google.protobuf import symbol_database as _symbol_database
# ----> 9 from google.protobuf.internal import builder as _builder
#      10 # @@protoc_insertion_point(imports)
#      12 _sym_db = _symbol_database.Default()
#
# ImportError: cannot import name 'builder' from 'google.protobuf.internal' (C:\Users\louis\AppData\Roaming\Python\Python310\site-packages\google\protobuf\internal\__init__.py)

# %%
! pip list
# Out:
# Package                       Version
# ----------------------------- ------------
# absl-py                       1.4.0
# annotated-types               0.6.0
# anyio                         4.2.0
# apache-beam                   2.46.0
# argon2-cffi                   23.1.0
# argon2-cffi-bindings          21.2.0
# array-record                  0.4.1
# arrow                         1.3.0
# asttokens                     2.4.1
# astunparse                    1.6.3
# async-lru                     2.0.4
# attrs                         23.1.0
# avro-python3                  1.10.2
# Babel                         2.14.0
# beautifulsoup4                4.12.2
# bleach                        6.1.0
# blinker                       1.7.0
# Brotli                        1.1.0
# cached-property               1.5.2
# cachetools                    5.3.2
# certifi                       2023.11.17
# cffi                          1.16.0
# charset-normalizer            3.3.2
# click                         8.1.7
# cloudpickle                   2.2.1
# colorama                      0.4.6
# comm                          0.2.0
# contextlib2                   21.6.0
# contourpy                     1.2.0
# crcmod                        1.7
# cycler                        0.12.1
# Cython                        3.0.9
# debugpy                       1.8.0
# decorator                     4.4.2
# defusedxml                    0.7.1
# dill                          0.3.1.1
# distro                        1.9.0
# dm-tree                       0.1.8
# docopt                        0.6.2
# entrypoints                   0.4
# etils                         1.7.0
# exceptiongroup                1.2.0
# executing                     2.0.1
# fastavro                      1.9.4
# fasteners                     0.19
# fastjsonschema                2.19.1
# Flask                         3.0.2
# flatbuffers                   23.5.26
# fonttools                     4.47.0
# fqdn                          1.5.1
# fsspec                        2024.3.1
# gast                          0.4.0
# gin-config                    0.5.0
# google-api-core               2.18.0
# google-api-python-client      2.124.0
# google-auth                   2.25.2
# google-auth-httplib2          0.2.0
# google-auth-oauthlib          0.4.6
# google-pasta                  0.2.0
# googleapis-common-protos      1.63.0
# grpcio                        1.60.0
# h11                           0.14.0
# h2                            4.1.0
# h5py                          3.10.0
# hdfs                          2.7.3
# hpack                         4.0.0
# httpcore                      1.0.2
# httplib2                      0.21.0
# httpx                         0.26.0
# hyperframe                    6.0.1
# idna                          3.6
# imageio                       2.33.1
# imageio-ffmpeg                0.4.9
# immutabledict                 4.2.0
# importlib_metadata            7.1.0
# importlib_resources           6.4.0
# ipykernel                     6.28.0
# ipython                       8.19.0
# ipywidgets                    8.1.2
# isoduration                   20.11.0
# itsdangerous                  2.1.2
# jax                           0.4.25
# jedi                          0.19.1
# Jinja2                        3.1.2
# joblib                        1.3.2
# json5                         0.9.14
# jsonpointer                   2.4
# jsonschema                    4.20.0
# jsonschema-specifications     2023.12.1
# jupyter                       1.0.0
# jupyter_client                8.6.0
# jupyter-console               6.6.3
# jupyter_core                  5.5.1
# jupyter-events                0.9.0
# jupyter-lsp                   2.2.1
# jupyter_server                2.12.1
# jupyter_server_terminals      0.5.1
# jupyterlab                    4.0.9
# jupyterlab_pygments           0.3.0
# jupyterlab_server             2.25.2
# jupyterlab_widgets            3.0.10
# kaggle                        1.6.8
# keras                         2.10.0
# Keras-Preprocessing           1.1.2
# kiwisolver                    1.4.5
# lazy_loader                   0.3
# libclang                      16.0.6
# lvis                          0.5.3
# lxml                          5.1.1
# Markdown                      3.5.1
# MarkupSafe                    2.1.3
# matplotlib                    3.8.2
# matplotlib-inline             0.1.6
# mistune                       3.0.2
# ml-dtypes                     0.3.2
# nbclient                      0.9.0
# nbconvert                     7.13.1
# nbformat                      5.9.2
# nest-asyncio                  1.5.8
# networkx                      3.2.1
# notebook                      7.0.6
# notebook_shim                 0.2.3
# numpy                         1.24.4
# oauth2client                  4.1.3
# oauthlib                      3.2.2
# object_detection              0.1
# objsize                       0.6.1
# openai                        1.6.1
# opencv-contrib-python         4.9.0.80
# opencv-python                 4.8.1.78
# opencv-python-headless        4.9.0.80
# opt-einsum                    3.3.0
# orjson                        3.10.0
# outcome                       1.3.0.post0
# overrides                     7.4.0
# packaging                     23.2
# pandas                        2.1.4
# pandocfilters                 1.5.0
# parso                         0.8.3
# pickleshare                   0.7.5
# Pillow                        10.1.0
# pip                           24.0
# pkgutil_resolve_name          1.3.10
# platformdirs                  4.1.0
# ply                           3.11
# portalocker                   2.8.2
# proglog                       0.1.10
# prometheus-client             0.19.0
# promise                       2.3
# prompt-toolkit                3.0.43
# proto-plus                    1.23.0
# protobuf                      3.19.6
# psutil                        5.9.7
# pure-eval                     0.2.2
# py-cpuinfo                    9.0.0
# pyarrow                       9.0.0
# pyasn1                        0.5.1
# pyasn1-modules                0.3.0
# pycocotools                   2.0.7
# pycparser                     2.21
# pydantic                      2.5.3
# pydantic_core                 2.14.6
# pydot                         1.4.2
# Pygments                      2.17.2
# pymongo                       3.13.0
# pyparsing                     2.4.7
# PyPDF2                        3.0.1
# PyQt5                         5.15.9
# PyQt5-sip                     12.12.2
# PySocks                       1.7.1
# python-dateutil               2.8.2
# python-json-logger            2.0.7
# python-slugify                8.0.4
# pytz                          2023.3.post1
# pywin32                       306
# pywinpty                      2.0.12
# PyYAML                        5.3.1
# pyzmq                         25.1.2
# qtconsole                     5.5.1
# QtPy                          2.4.1
# referencing                   0.32.0
# regex                         2023.12.25
# requests                      2.31.0
# requests-oauthlib             1.3.1
# rfc3339-validator             0.1.4
# rfc3986-validator             0.1.1
# rpds-py                       0.15.2
# rsa                           4.9
# sacrebleu                     2.2.0
# scikit-image                  0.22.0
# scikit-learn                  1.3.2
# scipy                         1.11.4
# seaborn                       0.13.0
# selenium                      4.16.0
# Send2Trash                    1.8.2
# sentencepiece                 0.2.0
# seqeval                       1.2.2
# setuptools                    69.2.0
# sip                           6.7.12
# six                           1.16.0
# sniffio                       1.3.0
# sortedcontainers              2.4.0
# sounddevice                   0.4.6
# soupsieve                     2.5
# stack-data                    0.6.3
# tabulate                      0.9.0
# tensorboard                   2.10.1
# tensorboard-data-server       0.6.1
# tensorboard-plugin-wit        1.8.1
# tensorflow                    2.10.0
# tensorflow-addons             0.22.0
# tensorflow-datasets           4.9.0
# tensorflow-estimator          2.10.0
# tensorflow-hub                0.16.1
# tensorflow-io                 0.31.0
# tensorflow-io-gcs-filesystem  0.31.0
# tensorflow-metadata           1.13.0
# tensorflow-model-optimization 0.8.0
# tensorflow-text               2.10.0
# termcolor                     2.4.0
# terminado                     0.18.0
# text-unidecode                1.3
# tf-keras                      2.15.0
# tf-models-official            2.10.1
# tf-slim                       1.1.0
# threadpoolctl                 3.2.0
# tifffile                      2023.12.9
# tinycss2                      1.2.1
# toml                          0.10.2
# tomli                         2.0.1
# tornado                       6.4
# tqdm                          4.66.1
# traitlets                     5.14.0
# trio                          0.24.0
# trio-websocket                0.11.1
# typeguard                     2.13.3
# types-python-dateutil         2.8.19.14
# typing_extensions             4.9.0
# typing-utils                  0.1.0
# tzdata                        2023.3
# uri-template                  1.3.0
# uritemplate                   4.1.1
# urllib3                       2.1.0
# wcwidth                       0.2.12
# webcolors                     1.13
# webencodings                  0.5.1
# websocket-client              1.7.0
# Werkzeug                      3.0.1
# wheel                         0.42.0
# widgetsnbextension            4.0.10
# win-inet-pton                 1.1.0
# wrapt                         1.16.0
# wsproto                       1.2.0
# zipp                          3.17.0
# zstandard                     0.22.0

# %% [markdown]
# ### Use model

# %% [markdown]
# ### Train model

# %% [markdown]
# ### Convert the model in TensorFlow.js
